# %% [markdown]
# <a href="https://colab.research.google.com/github/pabhishek101/100_Days_of_ML/blob/main/Day01_basic_operation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###Day 01 : Machine Learning

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Method to import dataset
# 1. Read data from zip file. ```!unzip <filepath_with name> -d <path>```
# 2. Read csv file. ```df=pd.read_csv()```
# 3. Read excel file. ```df=pd.read_excel()```
# 4. Read data from google drive.
# 5. Read data from aws s3.
# 6. Read data from google big query(lik s3).

# %%
# importing pandas library

import pandas as pd

# %%
# unzipping zip file

# !unzip /content/dataset_1.zip -d /content/
# Out:
# Archive:  /content/dataset_1.zip
#   inflating: /content/classData.csv
#   inflating: /content/detect_dataset.csv

# %%
# pulling data from csv file.
df=pd.read_csv('/content/classData.csv')
df.head()
# Out:
#    G  C  B  A          Ia          Ib          Ic        Va        Vb  \
# 0  1  0  0  1 -151.291812   -9.677452   85.800162  0.400750 -0.132935
# 1  1  0  0  1 -336.186183  -76.283262   18.328897  0.312732 -0.123633
# 2  1  0  0  1 -502.891583 -174.648023  -80.924663  0.265728 -0.114301
# 3  1  0  0  1 -593.941905 -217.703359 -124.891924  0.235511 -0.104940
# 4  1  0  0  1 -643.663617 -224.159427 -132.282815  0.209537 -0.095554
#
#          Vc
# 0 -0.267815
# 1 -0.189099
# 2 -0.151428
# 3 -0.130570
# 4 -0.113983

# %%
# pulling data from excel
df_1= pd.read_excel('/content/Mtech Elective choices.xlsx')
df_1.head()
# Out:
#                                                                             \
# 0                                           23565001
# 1                                           23566010
# 2                                           23565020
# 3                                           23565008
# 4                                           23565010
#
#   Course                       Name                   choice 1  \
# 0    NaN             Abhishek Patel  AID-565 - COMPUTER VISION
# 1    NaN        Rishabh Rajpurohit   AID-565 - COMPUTER VISION
# 2    NaN        Pilli Vishnuvardhan    AID-552 - DEEP LEARNING
# 3    NaN          Palzang Denzongpa    AID-552 - DEEP LEARNING
# 4    NaN  Pratik Priyadarshan Singh    AID-552 - DEEP LEARNING
#
#                            choice 2  \
# 0     AID-582 - RECOMMENDER SYSTEMS
# 1     AID-582 - RECOMMENDER SYSTEMS
# 2  AID-554 - REINFORCEMENT LEARNING
# 3         AID-565 - COMPUTER VISION
# 4         AID-565 - COMPUTER VISION
#
# ...

# %%
#mounting google drive

from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# reading and writing data into google drive.

#1. Reading data from google drive:

df_3=pd.read_csv('/content/drive/My Drive/detect_dataset.csv')


#2. Writing data into google drive.

current_dataset=df_3[['Ia','Ib','Ic']]
current_dataset.to_csv('/content/drive/My Drive/current_dataset.csv')

df_3.head()
# Out:
#    Unnamed: 0  Output (S)          Ia        Ib          Ic        Va  \
# 0           0           0 -170.472196  9.219613  161.252583  0.054490
# 1           1           0 -122.235754  6.168667  116.067087  0.102000
# 2           2           0  -90.161474  3.813632   86.347841  0.141026
# 3           3           0  -79.904916  2.398803   77.506112  0.156272
# 4           4           0  -63.885255  0.590667   63.294587  0.180451
#
#          Vb        Vc  Unnamed: 7  Unnamed: 8
# 0 -0.659921  0.605431         NaN         NaN
# 1 -0.628612  0.526202         NaN         NaN
# 2 -0.605277  0.464251         NaN         NaN
# 3 -0.602235  0.445963         NaN         NaN
# 4 -0.591501  0.411050         NaN         NaN
